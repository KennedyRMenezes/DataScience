# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv", sep=';')

# %%
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %%
df[df.columns[0]].value_counts(sort=False).sort_index()
# Out:
# Marital status
# 1    3919
# 2     379
# 3       4
# 4      91
# 5      25
# 6       6
# Name: count, dtype: int64

# %%
for col in range(len(df.columns)):
    print("*************")
    print(df[df.columns[col]].value_counts(sort=False).sort_index())
    print()
# Out:
# *************
# Marital status
# 1    3919
# 2     379
# 3       4
# 4      91
# 5      25
# 6       6
# Name: count, dtype: int64
#
# *************
# Application mode
# 1     1708
# 2        3
# 5       16
# 7      139
# 10      10
# 15      30
# 16      38
# 17     872
# 18     124
# 26       1
# 27       1
# 39     785
# 42      77
# 43     312
# 44     213
# 51      59
# 53      35
# 57       1
# Name: count, dtype: int64
#
# *************
# Application order
# 0       1
# 1    3026
# 2     547
# 3     309
# 4     249
# 5     154
# 6     137
# 9       1
# Name: count, dtype: int64
#
# *************
# Course
# 33       12
# 171     215
# 8014    215
# 9003    210
# 9070    226
# 9085    337
# 9119    170
# 9130    141
# 9147    380
# 9238    355
# 9254    252
# 9500    766
# 9556     86
# 9670    268
# 9773    331
# 9853    192
# 9991    268
# Name: count, dtype: int64
#
# *************
# Daytime/evening attendance\t
# 0     483
# 1    3941
# Name: count, dtype: int64
#
# ...
