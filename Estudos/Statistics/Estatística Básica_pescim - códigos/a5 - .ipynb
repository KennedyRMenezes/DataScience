# %%
a = [6,4,5,4,6]
b = [10,10,5,0,0]

# %%
import math

def desvP(a):
  media = sum(a)/len(a)
  sum_ = 0
  for i in a:
    sum_ += (i-media)**2

  variance = sum_/(len(a)-1)
  desv = math.sqrt(variance)

  return desv

# %%
print(desvP(a))
print(desvP(b))
# Out:
# 1.0
# 5.0
