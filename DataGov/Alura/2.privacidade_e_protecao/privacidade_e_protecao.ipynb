# %% [markdown]
# ## Instalando as bibliotecas

# %%
# !pip install DataProfiler[ml]

# %% [markdown]
# ## Importando as bibliotecas que serão usadas

# %%
from dataprofiler import Data, Profiler
import pandas as pd
import json

# %% [markdown]
# ## Importando os dados

# %%
dados = pd.read_csv("C:/Users/menez/KR/Programação/00.Estudos/DataSc/DataScience/DataGov/Alura/2.privacidade_e_protecao/autoridades_navais.csv", encoding='windows-1252')

# %% [markdown]
# ## Conhecendo os dados

# %%
dados
# Out:
#                                                CARGO  \
# 0                              Comandante da Marinha
# 1                    Chefe do Estado-Maior da Armada
# 2  Diretor-Geral de Desenvolvimento Nuclear e Tec...
# 3                     Comandante de Operações Navais
# 4                         Diretor-Geral de Navegação
# 5                Diretor-Geral do Pessoal da Marinha
# 6     Comandante-Geral do Corpo de Fuzileiros Navais
# 7                        Secretário-Geral da Marinha
# 8               Diretor-Geral do Material da Marinha
#
#                                                 NOME  \
# 0        Almirante de Esquadra Marcos Sampaio OLSEN
# 1  Almirante de Esquadra André Luiz SILVA LIMA de...
# 2  Almirante de Esquadra PETRONIO Augusto Siqueir...
# 3  Almirante de Esquadra Wladmilson BORGES de Agu...
# 4  Almirante de Esquadra Wladmilson BORGES de Agu...
# 5  Almirante de Esquadra Cláudio Henrique MELLO d...
# 6  Almirante de Esquadra (FN) CARLOS CHAGAS Viann...
# 7      Almirante de Esquadra Eduardo Machado VAZQUEZ
# 8  Almirante de Esquadra EDGAR Luiz Siqueira Barb...
#
#                                                   OM  \
# 0            GABINETE DO COMANDANTE DA MARINHA (GCM)
# 1                       ESTADO-MAIOR DA ARMADA (EMA)
# 2  DIRETORIA-GERAL DE DESENVOLVIMENTO NUCLEAR E T...
# 3             COMANDO DE OPERAÇÕES NAVAIS (ComOpNav)
# 4              DIRETORIA-GERAL DE  NAVEGAÇÃO  (DGN)
# 5  DIRETORIA-GERAL DO PESSOAL MILITAR DA MARINHA ...
# 6  COMANDO-GERAL DO CORPO DE FUZILEIROS NAVAIS (C...
# 7                  SECRETARIA-GERAL DA MARINHA (SGM)
# 8      DIRETORIA-GERAL DO MATERIAL DA MARINHA (DGMM)
#
#                                    ATRIBUIÇÕES DA OM  \
# 0  O GCM tem o propósito de assistir ao Comandant...
# 1  O EMA tem o propósito de assessorar o Comandan...
# 2  A DGDNTM, como um Órgão de Direção Setorial, t...
# 3  O ComOpNav tem o propósito de aprestar as Forç...
# 4  A DGN tem o propósito de contribuir para o pre...
# 5  A DGPM tem o propósito de contribuir para o pr...
# 6  O CGCFN tem como propósito dirigir, em âmbito ...
# 7  A SGM tem o propósito de contribuir para o pre...
# 8  A DGMM tem o propósito de contribuir para o pr...
#
#                                             ENDEREÇO         TELEFONE  \
# 0  Esplanada dos Ministérios, Bloco "N", 2º, 3º e...   (61) 3429-1001
# 1  Esplanada dos Ministérios, Bloco “N”. 5º andar...   (61) 3429–1045
# 2  Rua da Ponte - Ilha das Cobras S/Nº - Ed. 23 -...  (21) 2197-7561
# 3  Endereço: Praça Barão de Ladário, s/nº , Ed. A...   (21) 2104-6037
# 4  Praça Barão de Ladário, s/nº , Edifício Almira...  (21) 2104-7292
# 5  Praça Barão de Ladário, s/nº - Ed. Alte Tamand...   (21) 2104-5471
# 6  Ilha das Cobras, s/nº, Centro, Rio de Janeiro ...   (21) 2126-5015
# 7  Esplanada dos Ministérios, Bloco “N”, 6º andar...   (61) 3429-1127
# 8  Rua 1º de Março, 118, 10º ao 12º andar, Centro...   (21) 2104-2527
#
#              ASSISTENTE  \
# 0                   NaN
# 1   CC (AA) Alessandra
# 2      CC (AA) Peixoto
# 3         CF (T) Mendes
# 4         CF (T) Mendes
# 5             CC Bessa
# 6  CC (FN) Albuquerque
# 7           CC Maforte
# 8   CC Danilo Silveira
#
#   E-MAIL
# 0                                                NaN
# 1                alessandra.hypolito@marinha.mil.br
# 2                     ricardo.peixoto@marinha.mil.br
# 3                     mendes.oliveira@marinha.mil.br
# 4                     mendes.oliveira@marinha.mil.br
# 5                      rodrigo.bessa@marinha.mil.br
# 6                      j.albuquerque@marinha.mil.br
# 7                            maforte@marinha.mil.br
# 8                    danilo.silveira@marinha.mil.br

# %% [markdown]
# ## Criando um Profile a partir dos dados

# %%
profile = Profiler(dados)
# Out:
# WARNING:tensorflow:From C:\Users\menez\AppData\Roaming\Python\Python311\site-packages\keras\src\backend\tensorflow\core.py:192: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# INFO:DataProfiler.profilers.profile_builder: Finding the Null values in the columns...
# C:\Users\menez\AppData\Roaming\Python\Python311\site-packages\keras\src\saving\saving_lib.py:562: UserWarning: Skipping variable loading for optimizer 'adam', because it has 48 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 100%|██████████| 8/8 [00:00<00:00, 352.12it/s]
# INFO:DataProfiler.profilers.profile_builder: Calculating the statistics...
# 100%|██████████| 8/8 [00:01<00:00,  6.81it/s]

# %%
profile

# %%
report = profile.report(report_options={"output_format":"compact"})

# %%
report
# Out:
# {'global_stats': {'samples_used': 9,
#   'column_count': 8,
#   'row_count': 9,
#   'row_has_null_ratio': 0.1111,
#   'row_is_null_ratio': 0.0,
#   'unique_row_ratio': 1.0,
#   'duplicate_row_count': 0,
#   'file_type': "<class 'pandas.core.frame.DataFrame'>",
#   'encoding': None,
#   'correlation_matrix': None,
#   'chi2_matrix': '[[1.        , 0.32389696, 0.38884088, 0.38884088, 0.38884088, 0.38884088,\n  0.31886441, 0.31886441], ... , [0.31886441, 0.25617786, 0.31886441, 0.31886441, 0.31886441, 0.31886441,\n  0.24912985, 1.        ]]',
#   'profile_schema': {'CARGO': [0],
#    'NOME': [1],
#    'OM': [2],
#    'ATRIBUIÇÕES DA OM': [3],
#    'ENDEREÇO': [4],
#    'TELEFONE': [5],
#    'ASSISTENTE': [6],
#    'E-MAIL                                                                                                                                                                                                                                                                                                                                                                                                       ': [7]},
#   'times': {'row_stats': 0.0121}},
#  'data_stats': [{'column_name': 'CARGO',
#    'data_type': 'string',
#    'data_label': 'UNKNOWN',
#    'categorical': True,
#    'order': 'random',
#    'samples': "['Comandante da Marinha', 'Comandante-Geral do Corpo de Fuzileiros Navais',\n 'Diretor-Geral de Desenvolvimento Nuclear e Tecnológico da Marinha',\n 'Diretor-Geral do Material da Marinha', 'Chefe do Estado-Maior da Armada']",
#    'statistics': {'min': 21.0,
#     'max': 65.0,
#     'mode': '[21.022, 25.994, 27.006, 29.998, 31.01 ]',
#     'median': 31.01,
#     'sum': 317.0,
#     'mean': 35.2222,
#     'variance': 175.4444,
#     'stddev': 13.2455,
#     'skewness': 1.606,
#     'kurtosis': 2.8561,
#     'quantiles': {0: 26.995, 1: 31.01, 2: 35.993},
#     'median_abs_deviation': 4.972,
#     'vocab': "['F', 'D', 'g', 'C', 'ó', ... , 'ã', 'h', 'm', '-', 'd']",
#     'unique_count': 9,
#     'unique_ratio': 1.0,
#     'categories': "['Comandante da Marinha', ... , 'Diretor-Geral do Material da Marinha']",
#     'gini_impurity': 0.8889,
#     'unalikeability': 1.0,
#     'categorical_count': {'Comandante da Marinha': 1,
#      'Chefe do Estado-Maior da Armada': 1,
#      'Diretor-Geral de Desenvolvimento Nuclear e Tecnológico da Marinha': 1,
#      'Comandante de Operações Navais': 1,
#      'Diretor-Geral de Navegação': 1,
#      'Diretor-Geral do Pessoal da Marinha': 1,
#      'Comandante-Geral do Corpo de Fuzileiros Navais': 1,
#      'Secretário-Geral da Marinha': 1,
#      'Diretor-Geral do Material da Marinha': 1},
#     'sample_size': 9,
#     'null_count': 0,
#     'null_types': [],
#     'data_type_representation': {'datetime': 0.0,
#      'int': 0.0,
#      'float': 0.0,
#      'string': 1.0}}},
#   {'column_name': 'NOME',
#    'data_type': 'string',
#    'data_label': 'UNKNOWN',
#    'categorical': True,
#    'order': 'random',
#    'samples': "['Almirante de Esquadra\\xa0EDGAR\\xa0Luiz Siqueira Barbosa ',\n 'Almirante de Esquadra Wladmilson BORGES de Aguiar ',\n 'Almirante de Esquadra Cláudio Henrique MELLO de Almeida ',\n 'Almirante de Esquadra André Luiz\\xa0SILVA LIMA\\xa0de Santana Mendes ',\n 'Almirante de Esquadra Eduardo Machado\\xa0VAZQUEZ']",
#    'statistics': {'min': 43.0,
#     'max': 62.0,
#     'mode': '[50.0015]',
#     'median': 50.0078,
#     'sum': 468.0,
#     'mean': 52.0,
#     'variance': 37.25,
#     'stddev': 6.1033,
#     'skewness': 0.1357,
#     'kurtosis': -0.599,
#     'quantiles': {0: 49.9936, 1: 50.0078, 2: 56.0102},
#     'median_abs_deviation': 5.0033,
#     'vocab': "['L', 'I', 'F', 'B', '\\xa0', ... , 'm', '(', 'R', 'd', 'W']",
#     'unique_count': 8,
#     'unique_ratio': 0.8889,
#     'categories': "['Almirante de Esquadra Wladmilson BORGES de Aguiar ', ... , 'Almirante de Esquadra\\xa0EDGAR\\xa0Luiz Siqueira Barbosa ']",
#     'gini_impurity': 0.8642,
#     'unalikeability': 0.9722,
#     'categorical_count': {'Almirante de Esquadra Wladmilson BORGES de Aguiar ': 2,
#      'Almirante de Esquadra Marcos Sampaio\xa0OLSEN ': 1,
#      'Almirante de Esquadra André Luiz\xa0SILVA LIMA\xa0de Santana Mendes ': 1,
#      'Almirante de Esquadra PETRONIO Augusto Siqueira de Aguiar ': 1,
#      'Almirante de Esquadra Cláudio Henrique MELLO de Almeida ': 1,
#      'Almirante de Esquadra (FN)\xa0CARLOS CHAGAS\xa0Vianna Braga ': 1,
#      'Almirante de Esquadra Eduardo Machado\xa0VAZQUEZ': 1,
#      'Almirante de Esquadra\xa0EDGAR\xa0Luiz Siqueira Barbosa ': 1},
#     'sample_size': 9,
#     'null_count': 0,
#     'null_types': [],
#     'data_type_representation': {'datetime': 0.0,
#      'int': 0.0,
#      'float': 0.0,
#      'string': 1.0}}},
#   {'column_name': 'OM',
#    'data_type': 'string',
#    'data_label': 'UNKNOWN',
#    'categorical': True,
#    'order': 'random',
#    'samples': "['ESTADO-MAIOR DA ARMADA (EMA)',\n 'DIRETORIA-GERAL DO PESSOAL MILITAR DA MARINHA (DGPM)',\n 'COMANDO-GERAL DO CORPO DE FUZILEIROS NAVAIS (CGCFN)',\n 'DIRETORIA-GERAL DE DESENVOLVIMENTO NUCLEAR E TECNOLÓGICO DA MARINHA (DGDNTM) ',\n 'SECRETARIA-GERAL DA MARINHA (SGM)']",
#    'statistics': {'min': 28.0,
#     'max': 77.0,
#     'mode': '[28.0245, 33.0225, 36.9915, 38.0205, 39.0005]',
#     'median': 39.0005,
#     'sum': 400.0,
#     'mean': 44.4444,
#     'variance': 211.0278,
#     'stddev': 14.5268,
#     'skewness': 1.4905,
#     'kurtosis': 2.793,
#     'quantiles': {0: 36.9793, 1: 39.0005, 2: 51.0177},
#     'median_abs_deviation': 5.9903,
#     'vocab': "['I', 'L', 'F', 'B', 'D', ... , 'Z', '(', '-', 'm', 'R']",
#     'unique_count': 9,
#     'unique_ratio': 1.0,
#     'categories': "['GABINETE DO COMANDANTE DA MARINHA (GCM)', ... , 'DIRETORIA-GERAL DO MATERIAL DA MARINHA (DGMM)']",
#     'gini_impurity': 0.8889,
#     'unalikeability': 1.0,
#     'categorical_count': {'GABINETE DO COMANDANTE DA MARINHA (GCM)': 1,
#      'ESTADO-MAIOR DA ARMADA (EMA)': 1,
#      'DIRETORIA-GERAL DE DESENVOLVIMENTO NUCLEAR E TECNOLÓGICO DA MARINHA (DGDNTM) ': 1,
#      'COMANDO DE OPERAÇÕES NAVAIS (ComOpNav)': 1,
#      'DIRETORIA-GERAL DE \xa0NAVEGAÇÃO \xa0(DGN) ': 1,
#      'DIRETORIA-GERAL DO PESSOAL MILITAR DA MARINHA (DGPM)': 1,
#      'COMANDO-GERAL DO CORPO DE FUZILEIROS NAVAIS (CGCFN)': 1,
#      'SECRETARIA-GERAL DA MARINHA (SGM)': 1,
#      'DIRETORIA-GERAL DO MATERIAL DA MARINHA (DGMM)': 1},
#     'sample_size': 9,
#     'null_count': 0,
#     'null_types': [],
#     'data_type_representation': {'datetime': 0.0,
#      'int': 0.0,
#      'float': 0.0,
#      'string': 1.0}}},
#   {'column_name': 'ATRIBUIÇÕES DA OM',
#    'data_type': 'text',
#    'data_label': 'UNKNOWN',
#    'categorical': True,
#    'order': 'random',
#    'samples': "['A SGM tem o propósito de contribuir para o preparo e a aplicação do Poder Naval, no tocante às atividades relacionadas com:                                                                                                                                                                                                                                  \\n- Orçamento (Planejamento, Programação, Execução e Avaliação);                                                                                                                                                                                                                                                                                                                                                                                                            \\n- Economia e Finanças;                                                                                                                                                                                                                                                                                                                                                                                                                                                    \\n- Logística (Abastecimento);                                                                                                                                                                                                                                                                                                                                                                                                                                              \\n- Patrimônio Imobiliário e Histórico-Cultural;                                                                                                                                                                                                                                                                                                                                                                                                                            \\n- Sistemas Digitais Administrativos;                                                                                                                                                                                                                                                                                                                                                                                                                                      \\n- Administração Geral;                                                                                                                                                                                                                                                                                                                                                                                                                                                    \\n- Documentação;                                                                                                                                                                                                                                                                                                                                                                                                                                                           \\n- Controle Interno;                                                                                                                                                                                                                                                                                                                                                                                                  ...
#    'statistics': {'min': 270.0,
#     'max': 7785.0,
#     'mode': '[ 273.7575,  950.1075, 1303.3125, 1806.8175, 2873.9475]',
#     'median': 2873.9475,
#     'sum': 28726.0,
#     'mean': 3191.7778,
#     'variance': 5809358.9444,
#     'stddev': 2410.2612,
#     'skewness': 0.7005,
#     'kurtosis': 0.002,
#     'quantiles': {0: 1301.4337, 1: 2873.9475, 2: 4491.5512},
#     'median_abs_deviation': 1615.725,
#     'vocab': "['F', 'I', 'B', 'à', 'ó', ... , 'ô', 'b', '-', '(', 'R']",
#     'unique_count': 9,
#     'unique_ratio': 1.0,
#     'categories': "['O GCM tem o propósito de assistir ao Comandante da Marinha no desempenho das suas atribuições legais.                                                                                                                                                                                                                                                          \\nPara a consecução do propósito, cabem ao GCM as seguintes tarefas:                                                                                                                                                                                                                                                                                                                                                                                                        \\n- consolidar a documentação necessária às decisões do Comandante da Marinha;                                                                                                                                                                                                                                                                                                                                                                                              \\n- elaborar os documentos decorrentes das determinações do Comandante da Marinha; e                                                                                                                                                                                                                                                                                                                                                                                        \\n- exercer a assessoria de relações institucionais do Comandante da Marinha.', ... , 'A DGMM tem o propósito de contribuir para o preparo e aplicação do Poder Naval, no tocante às atividades relacionadas com o material e a tecnologia da informação da Marinha. Para a consecução do seu propósito, cabem a DGMM as tarefas de supervisionar os estudos para a formulação de diretrizes concernentes à produção, manutenção, desenvolvimento e pesquisas do material que lhe está afeto; supervisionar os projetos, a construção, a aquisição, a manutenção e os reparos de navios, aeronaves e equipamentos em geral; exercer a supervisão técnica do Sistema de Abastecimento da Marinha; e supervisionar as atividades relativas à Governança de Tecnologia da Informação na Marinha. Em situação de mobilização, conflito, estado de defesa, estado de sítio, intervenção federal e em regimes especiais, cabem a DGMM as tarefas que lhe forem atribuídas pelas Normas e Diretrizes referentes à Mobilização Marítima e as emanadas pelo Comandante da Marinha. ']",
#     'gini_impurity': 0.8889,
#     'unalikeability': 1.0,
#     'categorical_count': {'O GCM tem o propósito de assistir ao Comandante da Marinha no desempenho das suas atribuições legais.                                                                                                                                                                                                                                                          \nPara a consecução do propósito, cabem ao GCM as seguintes tarefas:                                                                                                                                                                                                                                                                                                                                                                                                        \n- consolidar a documentação necessária às decisões do Comandante da Marinha;                                                                                                                                                                                                                                                                                                                                                                                              \n- elaborar os documentos decorrentes das determinações do Comandante da Marinha; e                                                                                                                                                                                                                                                                                                                                                                                        \n- exercer a assessoria de relações institucionais do Comandante da Marinha.': 1,
#      'O EMA tem o propósito de assessorar o Comandante da Marinha na direção do Comando da Marinha e no desempenho de suas atribuições no Conselho Militar de Defesa e no Conselho de Defesa Nacional.                                                                                                                                                                  \nPara a consecução de seu propósito, cabem ao EMA as seguintes tarefas:                                                                                                                                                                                                                                                                                                                                                                                                    \n- coordenar e controlar as atividades que lhe forem atribuídas pelo Comandante da Mari-nha;                                                                                                                                                                                                                                                                                                                                                                               \n– formular a doutrina, a política e o planejamento estratégico da Marinha;                                                                                                                                                                                                                                                                                                                                                                                                \n– exercer a coordenação e o controle das atividades dos órgãos de Direção Setorial (ODS);                                                                                                                                                                                                                                                                                                                                                                                 \n- formular e acompanhar a execução do Programa de Reaparelhamento da Marinha (PRM);                                                                                                                                                                                                                                                                                                                                                                                       \n– controlar e coordenar a Política Marítima Nacional (PMN);                                                                                                                                                                                                                                                                                                                                                                                                               \n– supervisionar as atividades inerentes ao Plano Plurianual (PPA) do Governo Federal, na MB;                                                                                                                                                                                                                                                                                                                                                                              \n- exercer a direção-geral do Sistema do Plano Diretor (SPD);                                                                                                                                                                                                                                                                                                                                                                       ...
#      'A DGDNTM, como um Órgão de Direção Setorial, tem o propósito de atuar como o órgão central executivo do Sistema de Ciência, Tecnologia e Inovação da Marinha (SCTMB), exercendo a administração estratégica das atividades científicas, tecnológicas e de inovação da Marinha.': 1,
#      'O ComOpNav tem o propósito de aprestar as Forças Navais, Aeronavais e de Fuzileiros Navais para o adequado emprego do Poder Naval. Para tanto, cabem ao ComOpNav, entre outras, as seguintes tarefas:                                                                                                                                                       \n- orientar, coordenar e controlar as atividades do setor operativo concernentes à organização, ao pessoal, à justiça e disciplina, à legislação e as Diretrizes para o Planejamento Naval;                                                                                                                                                                                                                                                                                \n- supervisionar a prontificação, o adestramento e o emprego das Forças Navais, Aeronavais e de Fuzileiros Navais, inclusive as Distritais;                                                                                                                                                                                                                                                                                                                                \n- coordenar e controlar as atividades logísticas e de mobilização, necessárias à prontificação, ao adestramento e ao emprego de suas Forças;                                                                                                                                                                                                                                                                                                                              \n- supervisionar as atividades de Controle Naval e de Proteção ao Tráfego Marítimo, por meio da Organização do Controle Naval do Tráfego Marítimo (ORGACONTRAM);                                                                                                                                                                                                                                                                                                           \n- supervisionar o Serviço de Patrulha Naval executado pelos Distritos Navais;                                                                                                                                                                                                                                                                                                                                                                                             \n- supervisionar o Serviço de Busca e Salvamento de vida humana em perigo no mar, nos portos e nas vias navegáveis interiores, executado pelos Distritos Navais, exercer a função do Centro de Coordenação de Busca e Salvamento Marítimo do Brasil por intermédio do SALVAMAR BRASIL e dirigir as atividades de Busca e Salvamento da tripulação de submarino sinistrado;                                                                                                 \n- coordenar e controlar as atividades de assistência e salvamento de embarcação, coisa ou bem em perigo no mar, nos portos e nas vias navegáveis interiores;                                                                                                                                                                                                                                                                                                              \n- apoiar a Diretoria-Geral de Navegação (DGN), Organização Militar sem autonomia administrativa, integrada na estrutura organizacional do ComOpNav, no que concerne a pessoal, material e finanças, exercendo as atribuições que lhe competem, previstas em seu Regulamento; e                                                                                                                                                           ...
#      'A DGN tem o propósito de contribuir para o preparo e aplicação do Poder Naval e do Poder Marítimo, no tocante às atividades relacionadas com os assuntos marítimos, à segurança da navegação, à hidrografia, à oceanografia e à meteorologia.\n\nArt. 3 Para a consecução do seu propósito, cabem à DGN as seguintes tarefas:\n\nI – orientar, coordenar e controlar as atividades do setor da DGN concernentes à organização, pessoal, justiça e disciplina, legislação e Diretrizes Básicas da Marinha;\n\nII – participar na elaboração de propostas do dimensionamento das unidades subordinadas;\n\nIII – supervisionar a prontificação, o adestramento e o emprego de seus meios;\n\nIV – coordenar e controlar o apoio logístico necessário à prontificação, ao adestramento e ao emprego de seus meios;\n\nV – coordenar as atividades relacionadas com o conhecimento e a previsão do comportamento dos fatores ambientais na aplicação do Poder Naval;\n\nVI – coordenar as atividades voltadas para a segurança da navegação na área marítima de interesse do Brasil e nas vias navegáveis interiores;\n\nVII – supervisionar, no que se refere à Defesa Nacional e à segurança da navegação, as atividades relativas à Marinha Mercante e organizações correlatas envolvidas em atividades de pesquisa, de exploração e utilização de elementos marítimos.': 1,
#      'A DGPM tem o propósito de contribuir para o preparo e a aplicação do Poder Naval no tocante às atividades relacionadas com o pessoal da Marinha do Brasil (MB). Para a consecução do seu propósito, cabem à DGPM as seguintes tarefas:                                                                                  \n– orientar e controlar a atuação das Organizações Militares (OM) subordinadas;                                                                                                                                                                                                                                                                                                                                                                                            \n– determinar, aprovar e implementar os estudos e as diretrizes relativas ao Pessoal Militar e                                                                                                                                                                                                                                                                                                                                                                             \nCivil da MB, ao Ensino, à Saúde e à Assistência Social e Religiosa;                                                                                                                                                                                                                                                                                                                                                                                                       \n– supervisionar as atividades de Mobilização dos Subsistemas de Pessoal e Saúde, de Recrutamento, de Carreira, de Instrução, de Saúde e de Assistência Social e Religiosa; e                                                                                                                                                                                                                                                                                              \n – promover a formação da Reserva da Marinha.                                                                                                                                                                                                                                                                                                                                                                                                                             \n Em situação de mobilização, conflito, estado de defesa, estado de sítio, intervenção federal e em regimes especiais, cabem à DGPM as tarefas que lhe forem atribuídas pelas Normas e Diretrizes referentes à Mobilização Marítima e as emanadas pelo Comandante da Marinha.': 1,
#      'O CGCFN tem como propósito dirigir, em âmbito setorial, objetivando a excelência, as atividades relativas à Gestão Estratégica de Recursos Humanos, do Material de uso exclusivo ou preponderante do Corpo de Fuzileiros Navais (CFN) e buscar a eficácia das atividades de Educação Física e Desportiva na Mar\nPara consecução do seu propósito, cabem ao CGCFN as seguintes tarefas:                                                                                                                                                                                                                                                                                                                                                                                                    \n- elaborar, conduzir e divulgar a política para a gestão de pessoas no que tange aos Recursos Humanos próprios do CFN;                                                                                                                                                                                                                                                                                                                                                    \n- elaborar, conduzir e divulgar a política para a manutenção da capacidade operativa, para o reaparelhamento e modernização do CFN no que tange aos Recursos Materiais para emprego pelas Organizações Militares do CFN;                                                                                                                                                                                                                                                  \n- elaborar, conduzir e divulgar a política de Educação Física e Desportos para a Marinha do Brasil;                                                                                                                                                                                                                                                                                                                                                                       \n- elaborar, revisar, conduzir e divulgar a Doutrina para o preparo e emprego dos Fuzileiros Navais;                                                                                                                                                                                                                                                                                                                                                                       \n- supervisionar as atividades e os serviços Administrativos e Técnicos executados pelos seus Comandos Subordinados;                                                                                                                                                                                                                                                                                                                                                       \n- supervisionar a administração do pessoal que serve na OM/CGCFN;                                                                                                                                                                                                                                                                                                                                                                                                         \n- supervisionar as atividades relativas ao recrutamento e seleção de Recursos Humanos, bem como o preparo técnico profissional do pessoal do CFN;                                                                                                                                                                                                                                                                                                                         \n- supervi ...
#      'A SGM tem o propósito de contribuir para o preparo e a aplicação do Poder Naval, no tocante às atividades relacionadas com:                                                                                                                                                                                                                                  \n- Orçamento (Planejamento, Programação, Execução e Avaliação);                                                                                                                                                                                                                                                                                                                                                                                                            \n- Economia e Finanças;                                                                                                                                                                                                                                                                                                                                                                                                                                                    \n- Logística (Abastecimento);                                                                                                                                                                                                                                                                                                                                                                                                                                              \n- Patrimônio Imobiliário e Histórico-Cultural;                                                                                                                                                                                                                                                                                                                                                                                                                            \n- Sistemas Digitais Administrativos;                                                                                                                                                                                                                                                                                                                                                                                                                                      \n- Administração Geral;                                                                                                                                                                                                                                                                                                                                                                                                                                                    \n- Documentação;                                                                                                                                                                                                                                                                                                                                                                                                                                                           \n- Controle Interno;                                                                                                                                                                                                                                                                                                                                                                                                                     ...
#      'A DGMM tem o propósito de contribuir para o preparo e aplicação do Poder Naval, no tocante às atividades relacionadas com o material e a tecnologia da informação da Marinha. Para a consecução do seu propósito, cabem a DGMM as tarefas de supervisionar os estudos para a formulação de diretrizes concernentes à produção, manutenção, desenvolvimento e pesquisas do material que lhe está afeto; supervisionar os projetos, a construção, a aquisição, a manutenção e os reparos de navios, aeronaves e equipamentos em geral; exercer a supervisão técnica do Sistema de Abastecimento da Marinha; e supervisionar as atividades relativas à Governança de Tecnologia da Informação na Marinha. Em situação de mobilização, conflito, estado de defesa, estado de sítio, intervenção federal e em regimes especiais, cabem a DGMM as tarefas que lhe forem atribuídas pelas Normas e Diretrizes referentes à Mobilização Marítima e as emanadas pelo Comandante da Marinha. ': 1},
#     'sample_size': 9,
#     'null_count': 0,
#     'null_types': [],
#     'data_type_representation': {'datetime': 0.0,
#      'int': 0.0,
#      'float': 0.0,
#      'text': 1.0}}},
#   {'column_name': 'ENDEREÇO',
#    'data_type': 'string',
#    'data_label': 'UNKNOWN',
#    'categorical': True,
#    'order': 'random',
#    'samples': '[\'Endereço: Praça Barão de Ladário, s/nº , Ed. Alte Tamandaré, 6º/7º andares, Centro, RJ CEP.: 20091-000 \',\n \'Esplanada dos Ministérios, Bloco "N", 2º, 3º e 4º andar, Brasília, DF CEP: 70055-900\',\n \'Praça Barão de Ladário, s/nº - Ed. Alte Tamandaré, 7º andar, Centro – Rio de Janeiro, RJ CEP: 20091-000 \',\n \'Esplanada dos Ministérios, Bloco “N”. 5º andar, Brasília, DF CEP: 70055-900 \',\n \'Praça Barão de Ladário, s/nº , Edifício Almirante Dantas Torres S/N, Centro, RJ CEP.: 20091-000\']',
#    'statistics': {'min': 66.0,
#     'max': 104.0,
#     'mode': '[76.013]',
#     'median': 83.993,
#     'sum': 785.0,
#     'mean': 87.2222,
#     'variance': 188.1944,
#     'stddev': 13.7184,
#     'skewness': -0.0904,
#     'kurtosis': -1.488,
#     'quantiles': {0: 76.0177, 1: 83.993, 2: 100.0005},
#     'median_abs_deviation': 11.02,
#     'vocab': "['F', 'I', 'L', 'B', 'D', ... , '-', '.', 'm', 'R', 'd']",
#     'unique_count': 9,
#     'unique_ratio': 1.0,
#     'categories': '[\'Esplanada dos Ministérios, Bloco "N", 2º, 3º e 4º andar, Brasília, DF CEP: 70055-900\', ... , \'Rua 1º de Março, 118, 10º ao 12º andar, Centro, Rio de Janeiro, RJ CEP: 20010-000\']',
#     'gini_impurity': 0.8889,
#     'unalikeability': 1.0,
#     'categorical_count': {'Esplanada dos Ministérios, Bloco "N", 2º, 3º e 4º andar, Brasília, DF CEP: 70055-900': 1,
#      'Esplanada dos Ministérios, Bloco “N”. 5º andar, Brasília, DF CEP: 70055-900 ': 1,
#      'Rua da Ponte - Ilha das Cobras S/Nº - Ed. 23 - 2º Andar - Centro - Rio de Janeiro - RJ CEP 20091-000': 1,
#      'Endereço: Praça Barão de Ladário, s/nº , Ed. Alte Tamandaré, 6º/7º andares, Centro, RJ CEP.: 20091-000 ': 1,
#      'Praça Barão de Ladário, s/nº , Edifício Almirante Dantas Torres S/N, Centro, RJ CEP.: 20091-000': 1,
#      'Praça Barão de Ladário, s/nº - Ed. Alte Tamandaré, 7º andar, Centro – Rio de Janeiro, RJ CEP: 20091-000 ': 1,
#      'Ilha das Cobras, s/nº, Centro, Rio de Janeiro – RJ CEP: 20180-001 ': 1,
#      'Esplanada dos Ministérios, Bloco “N”, 6º andar, Brasília, DF CEP: 70055-900 ': 1,
#      'Rua 1º de Março, 118, 10º ao 12º andar, Centro, Rio de Janeiro, RJ CEP: 20010-000': 1},
#     'sample_size': 9,
#     'null_count': 0,
#     'null_types': [],
#     'data_type_representation': {'datetime': 0.0,
#      'int': 0.0,
#      'float': 0.0,
#      'string': 1.0}}},
#   {'column_name': 'TELEFONE',
#    'data_type': 'string',
#    'data_label': 'PHONE_NUMBER',
#    'categorical': True,
#    'order': 'random',
#    'samples': "['(61) 3429–1045', '(21) 2104-7292 ', ' (21) 2104-2527', '(21) 2126-5015',\n '(61) 3429-1001']",
#    'statistics': {'min': 14.0,
#     'max': 15.0,
#     'mode': '[14.0005]',
#     'median': 14.0008,
#     'sum': 129.0,
#     'mean': 14.3333,
#     'variance': 0.25,
#     'stddev': 0.5,
#     'skewness': 0.8571,
#     'kurtosis': -1.7143,
#     'quantiles': {0: 14.0004, 1: 14.0008, 2: 14.9992},
#     'median_abs_deviation': 0.0,
#     'vocab': "['–', '6', '2', '5', ' ', ... , '1', '-', '3', '4', '7']",
#     'unique_count': 9,
#     'unique_ratio': 1.0,
#     'categories': "['(61) 3429-1001', '(61) 3429–1045', ... , '(61) 3429-1127', ' (21) 2104-2527']",
#     'gini_impurity': 0.8889,
#     'unalikeability': 1.0,
#     'categorical_count': {'(61) 3429-1001': 1,
#      '(61) 3429–1045': 1,
#      '(21) 2197-7561 ': 1,
#      '(21) 2104-6037': 1,
#      '(21) 2104-7292 ': 1,
#      '(21) 2104-5471': 1,
#      '(21) 2126-5015': 1,
#      '(61) 3429-1127': 1,
#      ' (21) 2104-2527': 1},
#     'sample_size': 9,
#     'null_count': 0,
#     'null_types': [],
#     'data_type_representation': {'datetime': 0.0,
#      'int': 0.0,
#      'float': 0.0,
#      'string': 1.0}}},
#   {'column_name': 'ASSISTENTE',
#    'data_type': 'string',
#    'data_label': 'UNKNOWN',
#    'categorical': True,
#    'order': 'random',
#    'samples': "['CC Maforte ', 'CC (AA) Peixoto ', 'CF (T) Mendes',\n 'CC (FN) Albuquerque ', 'CC (AA) Alessandra ']",
#    'statistics': {'min': 9.0,
#     'max': 20.0,
#     'mode': '[12.9985, 19.0045]',
#     'median': 14.5,
#     'sum': 120.0,
#     'mean': 15.0,
#     'variance': 16.8571,
#     'stddev': 4.1057,
#     'skewness': -0.1156,
#     'kurtosis': -1.6158,
#     'quantiles': {0: 11.002, 1: 14.5, 2: 19.0045},
#     'median_abs_deviation': 4.004,
#     'vocab': "['F', 'B', 'D', 'f', ' ', ... , '(', 'q', 'd', 'n', 'v']",
#     'unique_count': 7,
#     'unique_ratio': 0.875,
#     'categories': "['CF (T) Mendes', 'CC (AA) Alessandra ', ... , 'CC Maforte ', 'CC Danilo Silveira ']",
#     'gini_impurity': 0.8438,
#     'unalikeability': 0.9643,
#     'categorical_count': {'CF (T) Mendes': 2,
#      'CC (AA) Alessandra ': 1,
#      'CC (AA) Peixoto ': 1,
#      'CC Bessa ': 1,
#      'CC (FN) Albuquerque ': 1,
#      'CC Maforte ': 1,
#      'CC Danilo Silveira ': 1},
#     'sample_size': 9,
#     'null_count': 1,
#     'null_types': "['nan']",
#     'data_type_representation': {'datetime': 0.0,
#      'int': 0.0,
#      'float': 0.0,
#      'string': 1.0}}},
#   {'column_name': 'E-MAIL                                                                                                                                                                                                                                                                                                                                                                                                       ',
#    'data_type': 'string',
#    'data_label': 'EMAIL_ADDRESS',
#    'categorical': True,
#    'order': 'random',
#    'samples': "['maforte@marinha.mil.br ', 'mendes.oliveira@marinha.mil.br',\n 'ricardo.peixoto@marinha.mil.br', 'mendes.oliveira@marinha.mil.br',\n 'alessandra.hypolito@marinha.mil.br ']",
#    'statistics': {'min': 23.0,
#     'max': 35.0,
#     'mode': '[30.002]',
#     'median': 30.0,
#     'sum': 237.0,
#     'mean': 29.625,
#     'variance': 10.8393,
#     'stddev': 3.2923,
#     'skewness': -0.7111,
#     'kurtosis': 3.1687,
#     'quantiles': {0: 29.006, 1: 30.0, 2: 30.008},
#     'median_abs_deviation': 0.9933,
#     'vocab': "['f', 'g', 'c', ' ', 'o', ... , '.', 'd', 'p', 'n', 'v']",
#     'unique_count': 7,
#     'unique_ratio': 0.875,
#     'categories': "['mendes.oliveira@marinha.mil.br', ... , 'danilo.silveira@marinha.mil.br ']",
#     'gini_impurity': 0.8438,
#     'unalikeability': 0.9643,
#     'categorical_count': {'mendes.oliveira@marinha.mil.br': 2,
#      'alessandra.hypolito@marinha.mil.br ': 1,
#      'ricardo.peixoto@marinha.mil.br': 1,
#      'rodrigo.bessa@marinha.mil.br ': 1,
#      'j.albuquerque@marinha.mil.br ': 1,
#      'maforte@marinha.mil.br ': 1,
#      'danilo.silveira@marinha.mil.br ': 1},
#     'sample_size': 9,
#     'null_count': 1,
#     'null_types': "['nan']",
#     'data_type_representation': {'datetime': 0.0,
#      'int': 0.0,
#      'float': 0.0,
#      'string': 1.0}}}]}

# %% [markdown]
# ## Analisando resultados do profile

# %% [markdown]
# # Usando a biblioteca Data Profiler para encontrar registros pessoais

# %% [markdown]
# ## Extraindo apenas a classificação de um report

# %% [markdown]
# ## Avaliando os resultados

# %% [markdown]
# # Criando uma Função para encontrar nomes de pessoas

# %% [markdown]
# ## Importando os nomes e sobrenomes mais comuns

# %% [markdown]
# ## Criando função que retira partículas (stopwords)

# %% [markdown]
# ## Importando classes improtantes

# %% [markdown]
# ## Criando a função que busca os nomes

# %% [markdown]
# ## Avaliando resultados
